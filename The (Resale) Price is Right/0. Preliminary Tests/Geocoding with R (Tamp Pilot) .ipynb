# %%
library(readr)
library(ggmap)
register_google(key="AIzaSyBgczf5a61gv-drXmko1tA9Wi53HJuqtn8", write=TRUE)
# Out:
# Warning message:
# "package 'readr' was built under R version 3.6.1"Warning message:
# "package 'ggmap' was built under R version 3.6.1"Loading required package: ggplot2
# Warning message:
# "package 'ggplot2' was built under R version 3.6.1"Google's Terms of Service: https://cloud.google.com/maps-platform/terms/.
# Please cite ggmap if you use it! See citation("ggmap") for details.
# Replacing old key (AIzaSyBgczf5a61gv) with new key in C:\Users\1995n\Documents/.Renviron

# %%
df <- read_csv("resale_tamp_18.csv")
head(df)
# Out:
# Parsed with column specification:
# cols(
#   month = col_character(),
#   town = col_character(),
#   flat_type = col_character(),
#   block = col_character(),
#   street_name = col_character(),
#   storey_range = col_character(),
#   floor_area_sqm = col_double(),
#   flat_model = col_character(),
#   lease_commence_date = col_double(),
#   remaining_lease = col_character(),
#   resale_price = col_double(),
#   address = col_character()
# )
#   month    town     flat_type block street_name    storey_range floor_area_sqm
# 1 1/1/2018 TAMPINES 3 ROOM    909   TAMPINES AVE 4 04 TO 06     73
# 2 1/1/2018 TAMPINES 3 ROOM    269   TAMPINES ST 21 04 TO 06     75
# 3 1/1/2018 TAMPINES 3 ROOM    285   TAMPINES ST 22 01 TO 03     74
# 4 1/1/2018 TAMPINES 3 ROOM    227   TAMPINES ST 23 10 TO 12     67
# 5 1/1/2018 TAMPINES 3 ROOM    424   TAMPINES ST 41 04 TO 06     74
# 6 1/1/2018 TAMPINES 3 ROOM    405   TAMPINES ST 41 04 TO 06     60
# ...

# %%
test <- ('909 Tampines Avenue 4')
test1 <- geocode(test)
test1

# %%
get_lon_lat <- function(x) {
    geocode(x)
}

# %%
library(dplyr)

lon_lat <- get_lon_lat(df$address)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.6.1"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=909+TAMPINES+AVE+4&key=xxx-drXmko1tA9Wi53HJuqtn8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=269+TAMPINES+ST+21&key=xxx-drXmko1tA9Wi53HJuqtn8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=285+TAMPINES+ST+22&key=xxx-drXmko1tA9Wi53HJuqtn8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=227+TAMPINES+ST+23&key=xxx-drXmko1tA9Wi53HJuqtn8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=424+TAMPINES+ST+41&key=xxx-drXmko1tA9Wi53HJuqtn8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=405+TAMPINES+ST+41&key=xxx-drXmko1tA9Wi53HJuqtn8
# ...

# %%
glimpse(lon_lat)
# Out:
# Observations: 1,368
# Variables: 2
# $ lon <dbl> 103.9394, 103.9483, 103.9531, 103.9550, 103.9482, 103.9449, 103...
# $ lat <dbl> 1.350256, 1.350496, 1.350139, 1.354703, 1.357433, 1.357782, 1.3...

# %%
df2 <- merge(df, lon_lat)

# %%
head(df2)
# Out:
#   month    town     flat_type block street_name    storey_range floor_area_sqm
# 1 1/1/2018 TAMPINES 3 ROOM    909   TAMPINES AVE 4 04 TO 06     73
# 2 1/1/2018 TAMPINES 3 ROOM    269   TAMPINES ST 21 04 TO 06     75
# 3 1/1/2018 TAMPINES 3 ROOM    285   TAMPINES ST 22 01 TO 03     74
# 4 1/1/2018 TAMPINES 3 ROOM    227   TAMPINES ST 23 10 TO 12     67
# 5 1/1/2018 TAMPINES 3 ROOM    424   TAMPINES ST 41 04 TO 06     74
# 6 1/1/2018 TAMPINES 3 ROOM    405   TAMPINES ST 41 04 TO 06     60
#   flat_model     lease_commence_date remaining_lease    resale_price
# 1 Model A        1984                65 years 03 months 330000
# 2 Model A        1984                65 years 02 months 350000
# 3 Model A        1984                65 years 06 months 315000
# 4 New Generation 1986                67 years 04 months 330000
# 5 Model A        1985                66 years 03 months 330000
# 6 Improved       1985                66 years 09 months 295000
#   address            lon      lat
# ...

# %%
head(df2)
